# %%
# !nvidia-smi
# !pip install -q ultralytics
# !pip install -q roboflow
# Out:
# Mon Apr 13 05:10:03 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from ultralytics import YOLO
from roboflow import Roboflow
import os
from IPython.display import display, Image
from IPython import display as ipd

# %%
ipd.clear_output()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
project_drive_path = ""
os.makedirs(project_drive_path, exist_ok=True)

# %%
rf = Roboflow(api_key="")
project = rf.workspace("").project("")
version = project.version(2)
dataset = version.download("")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Fruits-2 to yolov11:: 100%|██████████| 126405/126405 [00:01<00:00, 72983.48it/s]
# Extracting Dataset Version Zip to Fruits-2 in yolov11:: 100%|██████████| 6033/6033 [00:04<00:00, 1352.30it/s]

# %%
# !yolo task=detect mode=train \
    model=yolo11s.pt \
    data={dataset.location}/data.yaml \
    epochs=50 \
    imgsz=640 \
    save=True \
    save_period=1 \
    project={project_drive_path} \
    name="" \
    exist_ok=True
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Fruits-2/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=fruits_run_NEW, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_fruits_new_NEW, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW, save_frames=False, save_json=False, save_period=1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=16
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    825600  ultralytics.nn.modules.head.Detect           [16, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,433,984 parameters, 9,433,968 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 946.0±634.6 MB/s, size: 43.4 KB)
# train: Scanning /content/Fruits-2/train/labels... 2693 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2693/2693 2.0Kit/s 1.4s
# train: New cache created: /content/Fruits-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 845.2±523.5 MB/s, size: 48.6 KB)
# val: Scanning /content/Fruits-2/valid/labels... 210 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 210/210 938.2it/s 0.2s
# val: New cache created: /content/Fruits-2/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.0005, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.18G     0.9379       2.61      1.315         13        640: 100% ━━━━━━━━━━━━ 169/169 2.2it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3s/it 9.1s
#                    all        210        535      0.648      0.621      0.675      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.94G     0.9053      1.449      1.247         28        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.1s
#                    all        210        535      0.566       0.66      0.643      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.94G      0.926      1.349      1.243         26        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        210        535      0.711      0.564      0.639      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.94G     0.9258      1.264      1.238         33        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all        210        535      0.667      0.612      0.678      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.94G     0.9052      1.196      1.222         25        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all        210        535      0.693      0.666      0.703      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.94G     0.8894      1.156      1.218         44        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 59.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all        210        535      0.762      0.712      0.789      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.94G     0.8556       1.02      1.189         23        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 59.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all        210        535      0.805      0.714      0.792      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.94G      0.854      0.991      1.193         20        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.3s
#                    all        210        535      0.873      0.726      0.832      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.94G     0.8258     0.9213      1.168         27        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.9s
#                    all        210        535      0.806      0.735      0.838      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      4.94G     0.8145     0.8845      1.164         12        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 59.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.2s
#                    all        210        535      0.796       0.77      0.837      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      4.94G     0.7999     0.8614      1.159         17        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all        210        535      0.753      0.743      0.772      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      4.94G     0.7839     0.8196      1.148         51        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 59.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s
0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.94G     0.5678     0.4149      1.011         21        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 59.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        210        535      0.845      0.873      0.886      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.94G     0.5553     0.4017      1.005         16        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all        210        535      0.881      0.833      0.879      0.726
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      4.94G     0.4466     0.2834     0.9365          9        640: 100% ━━━━━━━━━━━━ 169/169 2.8it/s 60.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.3it/s 2.1s
#                    all        210        535      0.874      0.851      0.884      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      4.94G     0.4399     0.2711     0.9279          9        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 57.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all        210        535      0.877      0.834      0.874      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      4.94G     0.4232     0.2579     0.9208         16        640: 100% ━━━━━━━━━━━━ 169/169 3.0it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        210        535      0.881      0.838      0.872       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      4.94G     0.4173     0.2559     0.9193         12        640: 100% ━━━━━━━━━━━━ 169/169 3.0it/s 57.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all        210        535      0.859      0.853      0.877      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      4.94G     0.4084     0.2533     0.9213          6        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all        210        535      0.883      0.841      0.886      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      4.94G     0.3993     0.2425     0.9074         10        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all        210        535      0.886      0.847      0.876      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      4.94G     0.3886     0.2348     0.9069         13        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 57.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        210        535      0.861      0.857      0.872      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      4.94G     0.3797     0.2272     0.9026         10        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all        210        535      0.881      0.851      0.879      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      4.94G     0.3766     0.2225     0.8933         11        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all        210        535      0.877      0.853      0.877      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      4.94G     0.3675     0.2159     0.8912         13        640: 100% ━━━━━━━━━━━━ 169/169 2.9it/s 57.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        210        535      0.881      0.847      0.877      0.722
#
# 50 epochs completed in 0.870 hours.
# Optimizer stripped from /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW/weights/last.pt, 19.2MB
# Optimizer stripped from /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW/weights/best.pt, 19.2MB
#
# Validating /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW/weights/best.pt...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,418,992 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        210        535      0.883      0.841      0.886      0.729
#                  apple         11         31      0.905      0.968      0.987       0.83
#                 banana          8          9      0.679      0.943      0.886      0.778
#                 cherry          7         12      0.715      0.667      0.707      0.597
#                coconut         18         31      0.994          1      0.995      0.864
#               cucumber         15         41      0.917      0.878      0.911      0.672
#                  grape          8         18      0.876        0.5      0.664      0.455
#                   kiwi         22         97       0.93      0.804      0.871      0.736
#                  mango         14         29      0.595      0.345      0.489      0.387
#                  melon         20         32          1      0.994      0.995        0.9
#                 orange         19         77      0.965      0.721      0.949      0.812
#                  peach         14         45      0.885      0.851      0.946      0.767
#                   pear         14         27      0.819          1      0.893      0.732
#              pineapple         15         17          1      0.973      0.995      0.845
#            pomegranate          9         13      0.904          1      0.984      0.744
#             strawberry          9         35      0.998      0.857       0.91      0.664
#             watermelon         15         21      0.952      0.955      0.991      0.876
# Speed: 0.2ms preprocess, 5.7ms inference, 0.0ms loss, 7.0ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_fruits_new_NEW/fruits_run_NEW
# 💡 Learn more at https://docs.ultralytics.com/modes/train
